# %%
# imports library 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
file_path ='../World_energy_consumption/Raw_data_files/Primary_energy_consumption.csv'
df_1= pd.read_csv(file_path, skiprows=2, encoding='unicode_escape')
df_1.head()
# Out:
#              Exajoules   1965   1966   1967   1968   1969   1970   1971  \
# 0                  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1               Canada   5.00   5.32   5.57   5.92   6.28   6.73   6.94
# 2               Mexico   1.06   1.12   1.14   1.24   1.36   1.45   1.53
# 3                   US  51.98  54.89  56.80  60.19  63.30  65.54  66.92
# 4  Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39
#
#     1972   1973  ...    2016    2017    2018    2019    2020    2021    2022  \
# 0    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   7.47   8.11  ...   14.32   14.54   14.67   14.59   13.71   13.84   14.14
# 2   1.69   1.82  ...    8.11    8.26    8.16    8.06    7.43    7.99    8.73
# 3  70.25  73.22  ...   92.60   92.95   96.35   95.67   88.57   93.40   95.91
# 4  79.41  83.16  ...  115.04  115.76  119.18  118.32  109.71  115.23  118.78
#
#   2022.1 2012-22 2022.2
# 0    NaN     NaN    NaN
# ...

# %%
rename_dict = {'Exajoules':'Country','2022.1':'Growth rate 2022-2021 in %','2012-22':'Growth rate 2022-2012 in %', '2022.2':'Share 2022 in %' }

# %%
df_1.rename(columns=rename_dict, inplace=True)
df = df_1.rename(columns=rename_dict)
df.head()
# Out:
#                Country   1965   1966   1967   1968   1969   1970   1971  \
# 0                  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1               Canada   5.00   5.32   5.57   5.92   6.28   6.73   6.94
# 2               Mexico   1.06   1.12   1.14   1.24   1.36   1.45   1.53
# 3                   US  51.98  54.89  56.80  60.19  63.30  65.54  66.92
# 4  Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39
#
#     1972   1973  ...    2016    2017    2018    2019    2020    2021    2022  \
# 0    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1   7.47   8.11  ...   14.32   14.54   14.67   14.59   13.71   13.84   14.14
# 2   1.69   1.82  ...    8.11    8.26    8.16    8.06    7.43    7.99    8.73
# 3  70.25  73.22  ...   92.60   92.95   96.35   95.67   88.57   93.40   95.91
# 4  79.41  83.16  ...  115.04  115.76  119.18  118.32  109.71  115.23  118.78
#
# ...

# %%
df=df.drop([0,0])

# %%
df.shape
# Out:
# (126, 62)

# %%
df.count()
# Out:
# Country                       110
# 1965                          103
# 1966                          103
# 1967                          103
# 1968                          103
#                              ...
# 2021                          103
# 2022                          103
# Growth rate 2022-2021 in %    103
# Growth rate 2022-2012 in %    103
# Share 2022 in %               103
# Length: 62, dtype: int64

# %%
df.isnull().sum()
# Out:
# Country                       16
# 1965                          23
# 1966                          23
# 1967                          23
# 1968                          23
#                               ..
# 2021                          23
# 2022                          23
# Growth rate 2022-2021 in %    23
# Growth rate 2022-2012 in %    23
# Share 2022 in %               23
# Length: 62, dtype: int64

# %%
df.set_index('Country', inplace=True)

# %%
df.head()
# Out:
#                       1965   1966   1967   1968   1969   1970   1971   1972  \
# Country
# Canada                5.00   5.32   5.57   5.92   6.28   6.73   6.94   7.47
# Mexico                1.06   1.12   1.14   1.24   1.36   1.45   1.53   1.69
# US                   51.98  54.89  56.80  60.19  63.30  65.54  66.92  70.25
# Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39  79.41
# NaN                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                       1973   1974  ...    2016    2017    2018    2019  \
# Country                            ...
# Canada                8.11   8.36  ...   14.32   14.54   14.67   14.59
# Mexico                1.82   2.01  ...    8.11    8.26    8.16    8.06
# US                   73.22  71.43  ...   92.60   92.95   96.35   95.67
# Total North America  83.16  81.81  ...  115.04  115.76  119.18  118.32
# NaN                    NaN    NaN  ...     NaN     NaN     NaN     NaN
#
# ...

# %%
null_rows= df.isna().any(axis=1)

# %%
index_with_nulls = df.index[null_rows].tolist()

print(index_with_nulls)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, '* In this review, primary energy comprises commercially-traded fuels, including modern renewables used to generate electricity. ', 'Energy from all sources of non-fossil power generation is accounted for on an input-equivalent basis. See the appendix or https://www.energyinst.org/statistical-review for more details on this methodology.', '^ Less than 0.005.', 'w Less than 0.05%.', 'n/a not available.', 'USSR includes CIS, Georgia, Ukraine and the Baltic States.', '#Excludes Estonia, Latvia and Lithuania prior to 1985 and Slovenia prior to 1990.', nan, nan, nan, nan, nan, nan, nan, nan]

# %%
df_new = df.drop(index_with_nulls)
df_new.head()
# Out:
#                       1965   1966   1967   1968   1969   1970   1971   1972  \
# Country
# Canada                5.00   5.32   5.57   5.92   6.28   6.73   6.94   7.47
# Mexico                1.06   1.12   1.14   1.24   1.36   1.45   1.53   1.69
# US                   51.98  54.89  56.80  60.19  63.30  65.54  66.92  70.25
# Total North America  58.04  61.33  63.51  67.36  70.95  73.72  75.39  79.41
# Argentina             1.18   1.22   1.26   1.30   1.34   1.27   1.35   1.37
#
#                       1973   1974  ...    2016    2017    2018    2019  \
# Country                            ...
# Canada                8.11   8.36  ...   14.32   14.54   14.67   14.59
# Mexico                1.82   2.01  ...    8.11    8.26    8.16    8.06
# US                   73.22  71.43  ...   92.60   92.95   96.35   95.67
# Total North America  83.16  81.81  ...  115.04  115.76  119.18  118.32
# Argentina             1.43   1.48  ...    3.57    3.57    3.54    3.34
#
# ...

# %%
df_new.isnull().sum()
# Out:
# 1965                          0
# 1966                          0
# 1967                          0
# 1968                          0
# 1969                          0
#                              ..
# 2021                          0
# 2022                          0
# Growth rate 2022-2021 in %    0
# Growth rate 2022-2012 in %    0
# Share 2022 in %               0
# Length: 61, dtype: int64

# %%
df_new.dtypes
# Out:
# 1965                          object
# 1966                          object
# 1967                          object
# 1968                          object
# 1969                          object
#                                ...
# 2021                          object
# 2022                          object
# Growth rate 2022-2021 in %    object
# Growth rate 2022-2012 in %    object
# Share 2022 in %               object
# Length: 61, dtype: object

# %%
columns_to_convert = df_new.columns[:-3]

# %%
for column in columns_to_convert:
    df_new[column] = pd.to_numeric(df_new[column], errors='coerce')
    
df_new.dtypes
# Out:
# 1965                          float64
# 1966                          float64
# 1967                          float64
# 1968                          float64
# 1969                          float64
#                                ...
# 2021                          float64
# 2022                          float64
# Growth rate 2022-2021 in %     object
# Growth rate 2022-2012 in %     object
# Share 2022 in %                object
# Length: 61, dtype: object

# %%
# Get full rows based on the index of top values in 'Growth rate 2022-2021'
top_five_2022 = df_new['2022'].nlargest(5)

print(top_five_2022)
# Out:
# Country
# Total World                  604.04
#                  Non-OECD    369.62
# Total Asia Pacific           277.60
# of which: OECD               234.42
# China                        159.39
# Name: 2022, dtype: float64

# %%
# Function to convert percentage strings to float and handle non-numeric values
def convert_percent_to_float(df_new_column):
    # Replace '%' and handle non-numeric entries
    return pd.to_numeric(df_new_column.str.replace('%', '').replace('-', np.nan), errors='coerce')

# Applying the conversion function to the last three columns
df_new['Growth rate 2022-2021 in %'] = convert_percent_to_float(df_new['Growth rate 2022-2021 in %'])
df_new['Growth rate 2022-2012 in %'] = convert_percent_to_float(df_new['Growth rate 2022-2012 in %'])
df_new['Share 2022 in %'] = convert_percent_to_float(df_new['Share 2022 in %'])

# Output the updated Data type in the dataframe
df_new.dtypes
# Out:
# 1965                          float64
# 1966                          float64
# 1967                          float64
# 1968                          float64
# 1969                          float64
#                                ...
# 2021                          float64
# 2022                          float64
# Growth rate 2022-2021 in %    float64
# Growth rate 2022-2012 in %    float64
# Share 2022 in %               float64
# Length: 61, dtype: object

# %%
# Dropping rows where any cell has NaN
df_new.dropna(inplace=True)

# Output the updated DataFrame
df_new.head(30)
# Out:
#                            1965   1966   1967   1968   1969   1970   1971  \
# Country
# Canada                     5.00   5.32   5.57   5.92   6.28   6.73   6.94
# Mexico                     1.06   1.12   1.14   1.24   1.36   1.45   1.53
# US                        51.98  54.89  56.80  60.19  63.30  65.54  66.92
# Total North America       58.04  61.33  63.51  67.36  70.95  73.72  75.39
# Argentina                  1.18   1.22   1.26   1.30   1.34   1.27   1.35
# Brazil                     0.99   1.08   1.11   1.27   1.39   1.63   1.82
# Chile                      0.26   0.28   0.29   0.28   0.31   0.32   0.35
# Colombia                   0.35   0.40   0.42   0.43   0.44   0.48   0.48
# Ecuador                    0.03   0.03   0.04   0.04   0.04   0.05   0.06
# Peru                       0.20   0.24   0.25   0.25   0.25   0.26   0.27
# Trinidad & Tobago          0.12   0.13   0.14   0.14   0.15   0.16   0.16
# ...

# %%
# Create the output file (CSV)

output_data_file = "../World_energy_consumption/Clean_data_files/Energy_data.csv"


# Export the DataFrame to a CSV file
df_new.to_csv(output_data_file, index="Country")
